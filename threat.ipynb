# %% [markdown]
# <a href="https://colab.research.google.com/github/aabs9/new1/blob/master/threat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# هذا يسمح لك برفع الملفات من جهازك
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8b80d5c9-03ec-440c-bf17-aa9c718f3cc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b80d5c9-03ec-440c-bf17-aa9c718f3cc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install numpy pandas tensorflow

# %%
# !python train_dnn.py

# %%
from google.colab import files
import os

# رفع الملفات أو المجلد
uploaded = files.upload()

# %%
from google.colab import files
import os

# رفع ملفات CSV مباشرة
uploaded = files.upload()

# إنشاء مجلد dataset لتنظيم الملفات
os.makedirs("dataset", exist_ok=True)

# نقل كل الملفات المرفوعة إلى مجلد dataset
for file_name in uploaded.keys():
    os.rename(file_name, os.path.join("dataset", file_name))

# %%
import os

# إنشاء مجلد dataset
os.makedirs("dataset", exist_ok=True)

# نقل جميع ملفات CSV إلى مجلد dataset
for file in os.listdir():
    if file.endswith(".csv"):
        os.rename(file, os.path.join("dataset", file))

print("✅ تم نقل كل ملفات CICIDS2017 إلى dataset/")
# !ls dataset

# %%
# !python app.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-907070862.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# ضغط كل الملفات والمجلدات المهمة في ملف واحد
# !zip -r project.zip dataset templates models app.py logic.py train_dnn.py

# تنزيل الملف المضغوط مباشرة
from google.colab import files
files.download("project.zip")
# Out:
#   adding: dataset/ (stored 0%)
#   adding: dataset/Monday-WorkingHours.pcap_ISCX.csv (deflated 70%)
#   adding: dataset/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv (deflated 75%)
#   adding: dataset/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv (deflated 76%)
#   adding: dataset/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv (deflated 71%)
#   adding: dataset/Wednesday-workingHours.pcap_ISCX.csv (deflated 73%)
#   adding: dataset/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv (deflated 83%)
#   adding: dataset/Friday-WorkingHours-Morning.pcap_ISCX.csv (deflated 72%)
#   adding: dataset/Tuesday-WorkingHours.pcap_ISCX.csv (deflated 71%)
#   adding: templates/ (stored 0%)
#   adding: templates/index.html (deflated 56%)
#   adding: templates/.ipynb_checkpoints/ (stored 0%)
#   adding: models/ (stored 0%)
#   adding: models/dnn_cyber_model.h5 (deflated 24%)
#   adding: app.py (deflated 48%)
#   adding: logic.py (deflated 46%)
# ...
